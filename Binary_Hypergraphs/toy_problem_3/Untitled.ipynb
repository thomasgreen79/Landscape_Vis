# %%
library(tidyverse)

# %%
raw_data = read.csv("./data/int_graph_data_5_bit.csv")
raw_data1 = read.csv("./data/int_graph_data_5_bit_1.csv")

# %%
ggplot(raw_data) +
  aes(x=x, y=f_x) +
  geom_line()
# Out:
# plot without title

# %%
evens = raw_data1 %>% 
            filter(x%%2 == 0)
odds = raw_data1 %>% 
            filter(x%%2 == 1)

# %%
ggplot(evens) +
  aes(x=x, y=f_x) +
  geom_line()
# Out:
# plot without title

# %%
ggplot(odds) +
  aes(x=x, y=f_x) +
  geom_line()
# Out:
# plot without title
