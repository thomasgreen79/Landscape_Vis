# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
raw_data_30 = read.csv("../data/knapsack_problem_14_bit_30_wt_data.csv")
raw_data_77 = read.csv("../data/knapsack_problem_14_bit_77_wt_data.csv")
raw_data_90 = read.csv("../data/knapsack_problem_14_bit_90_wt_data.csv")
raw_data_120 = read.csv("../data/knapsack_problem_14_bit_120_wt_data.csv")

# %%
raw_data_30$eigenbin <- cut(raw_data_30$eigencentrality, seq(0.0,1.1,0.04), right=FALSE)
raw_data_77$eigenbin <- cut(raw_data_77$eigencentrality, seq(0.0,1.1,0.04), right=FALSE)
raw_data_90$eigenbin <- cut(raw_data_90$eigencentrality, seq(0.0,1.1,0.04), right=FALSE)
raw_data_120$eigenbin <- cut(raw_data_120$eigencentrality, seq(0.0,1.1,0.04), right=FALSE)

# %%
raw_data_30 %>%
  ggplot(aes(x=eigencentrality, y=is_peak)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_77 %>%
  ggplot(aes(x=eigencentrality, y=is_peak)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_90 %>%
  ggplot(aes(x=eigencentrality, y=is_peak)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_120 %>%
  ggplot(aes(x=eigencentrality, y=is_peak)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_30 = raw_data_30 %>%
    group_by(eigenbin) %>%
    summarise(total_in_bin = n(), peak_counts = sum(is_peak == "True")) %>%
    mutate(percent = peak_counts/total_in_bin)
peak_data_77 = raw_data_77 %>%
    group_by(eigenbin) %>%
    summarise(total_in_bin = n(), peak_counts = sum(is_peak == "True")) %>%
    mutate(percent = peak_counts/total_in_bin)
peak_data_90 = raw_data_90 %>%
    group_by(eigenbin) %>%
    summarise(total_in_bin = n(), peak_counts = sum(is_peak == "True")) %>%
    mutate(percent = peak_counts/total_in_bin)
peak_data_120 = raw_data_120 %>%
    group_by(eigenbin) %>%
    summarise(total_in_bin = n(), peak_counts = sum(is_peak == "True")) %>%
    mutate(percent = peak_counts/total_in_bin)

# %%
peak_data_30 %>%
  ggplot(aes(x=eigenbin, y=peak_counts)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_77 %>%
  ggplot(aes(x=eigenbin, y=peak_counts)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_90 %>%
  ggplot(aes(x=eigenbin, y=peak_counts)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_120 %>%
  ggplot(aes(x=eigenbin, y=peak_counts)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_30 %>%
  ggplot(aes(x=eigenbin, y=percent)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_77 %>%
  ggplot(aes(x=eigenbin, y=percent)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_90 %>%
  ggplot(aes(x=eigenbin, y=percent)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_120 %>%
  ggplot(aes(x=eigenbin, y=percent)) +
  geom_point()
# Out:
# plot without title

# %%
peak_data_30
# Out:
#    eigenbin    total_in_bin peak_counts percent
# 1  [0,0.04)    16063        11866       0.7387163
# 2  [0.04,0.08)    69            7       0.1014493
# 3  [0.08,0.12)    24           10       0.4166667
# 4  [0.12,0.16)    24           21       0.8750000
# 5  [0.16,0.2)     21           21       1.0000000
# 6  [0.2,0.24)     24           23       0.9583333
# 7  [0.24,0.28)    21           21       1.0000000
# 8  [0.28,0.32)    19           19       1.0000000
# 9  [0.32,0.36)    28           28       1.0000000
# 10 [0.36,0.4)     25           25       1.0000000
# 11 [0.4,0.44)     21           21       1.0000000
# 12 [0.44,0.48)    11           11       1.0000000
# 13 [0.48,0.52)     9            9       1.0000000
# 14 [0.52,0.56)     8            8       1.0000000
# 15 [0.56,0.6)      5            5       1.0000000
# 16 [0.6,0.64)      4            4       1.0000000
# 17 [0.64,0.68)     4            4       1.0000000
# 18 [0.68,0.72)     1            1       1.0000000
# 19 [0.76,0.8)      2            2       1.0000000
# 20 [1,1.04)        1            1       1.0000000

# %%
peak_data_77
# Out:
#    eigenbin    total_in_bin peak_counts percent
# 1  [0,0.04)    15527        165         0.01062665
# 2  [0.04,0.08)   352         34         0.09659091
# 3  [0.08,0.12)   132         29         0.21969697
# 4  [0.12,0.16)    65         40         0.61538462
# 5  [0.16,0.2)     54         36         0.66666667
# 6  [0.2,0.24)     48         40         0.83333333
# 7  [0.24,0.28)    36         30         0.83333333
# 8  [0.28,0.32)    26         24         0.92307692
# 9  [0.32,0.36)    20         20         1.00000000
# 10 [0.36,0.4)     28         28         1.00000000
# 11 [0.4,0.44)     19         19         1.00000000
# 12 [0.44,0.48)    16         16         1.00000000
# 13 [0.48,0.52)    11         11         1.00000000
# 14 [0.52,0.56)    10         10         1.00000000
# 15 [0.56,0.6)      9          9         1.00000000
# 16 [0.6,0.64)      3          3         1.00000000
# 17 [0.64,0.68)     5          5         1.00000000
# 18 [0.68,0.72)     6          6         1.00000000
# 19 [0.72,0.76)     3          3         1.00000000
# 20 [0.76,0.8)      4          4         1.00000000
# 21 [0.8,0.84)      4          4         1.00000000
# 22 [0.84,0.88)     2          2         1.00000000
# 23 [0.88,0.92)     3          3         1.00000000
# 24 [1,1.04)        1          1         1.00000000

# %%
peak_data_90
# Out:
#    eigenbin    total_in_bin peak_counts percent
# 1  [0,0.04)    15447         5          0.0003236874
# 2  [0.04,0.08)   681         7          0.0102790015
# 3  [0.08,0.12)    95         8          0.0842105263
# 4  [0.12,0.16)    24         9          0.3750000000
# 5  [0.16,0.2)     35         6          0.1714285714
# 6  [0.2,0.24)     25        18          0.7200000000
# 7  [0.24,0.28)     9         5          0.5555555556
# 8  [0.28,0.32)    13         9          0.6923076923
# 9  [0.32,0.36)     7         7          1.0000000000
# 10 [0.36,0.4)      7         6          0.8571428571
# 11 [0.4,0.44)      6         6          1.0000000000
# 12 [0.44,0.48)     6         6          1.0000000000
# 13 [0.48,0.52)     5         5          1.0000000000
# 14 [0.52,0.56)     5         5          1.0000000000
# 15 [0.56,0.6)      2         2          1.0000000000
# 16 [0.6,0.64)      3         3          1.0000000000
# 17 [0.64,0.68)     4         4          1.0000000000
# 18 [0.68,0.72)     4         4          1.0000000000
# 19 [0.72,0.76)     1         1          1.0000000000
# 20 [0.76,0.8)      1         1          1.0000000000
# 21 [0.8,0.84)      1         1          1.0000000000
# 22 [0.84,0.88)     2         2          1.0000000000
# 23 [1,1.04)        1         1          1.0000000000

# %%
peak_data_120
# Out:
#    eigenbin    total_in_bin peak_counts percent
# 1  [0,0.04)    15872        0           0
# 2  [0.04,0.08)   384        0           0
# 3  [0.08,0.12)    64        0           0
# 4  [0.12,0.16)    32        0           0
# 5  [0.16,0.2)     16        0           0
# 6  [0.24,0.28)     8        0           0
# 7  [0.32,0.36)     4        0           0
# 8  [0.44,0.48)     2        0           0
# 9  [0.56,0.6)      1        0           0
# 10 [1,1.04)        1        1           1

# %%
raw_data_30 %>%
  ggplot(aes(x=eigencentrality, y=fitness)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_77 %>%
  ggplot(aes(x=eigencentrality, y=fitness)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_90 %>%
  ggplot(aes(x=eigencentrality, y=fitness)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_120 %>%
  ggplot(aes(x=eigencentrality, y=fitness)) +
  geom_point()
# Out:
# plot without title

# %%
raw_data_77 %>%
  filter(eigencentrality >= 0.24) %>%
  filter(eigencentrality < 1) %>%
  filter(fitness < 350)
# Out:
#   id    eigencentrality is_peak fitness eigenbin
# 1 16245 0.2467684       True    349     [0.24,0.28)

# %%
raw_data_90 %>%
  filter(eigencentrality >= 0.2) %>%
  filter(eigencentrality < 0.24)
# Out:
#    id    eigencentrality is_peak fitness eigenbin
# 1   1279 0.2373625       True    426     [0.2,0.24)
# 2   2015 0.2277002       True    419     [0.2,0.24)
# 3   2943 0.2071098       True    417     [0.2,0.24)
# 4   3838 0.2180379       True    422     [0.2,0.24)
# 5   4087 0.2020270       True    417     [0.2,0.24)
# 6   7415 0.2107327       True    429     [0.2,0.24)
# 7   7662 0.2166360       False   432     [0.2,0.24)
# 8   7933 0.2252062       True    426     [0.2,0.24)
# 9   9951 0.2180379       True    424     [0.2,0.24)
# 10 11006 0.2277002       True    430     [0.2,0.24)
# 11 11711 0.2254102       False   436     [0.2,0.24)
# 12 11773 0.2305269       True    428     [0.2,0.24)
# 13 12270 0.2180379       True    425     [0.2,0.24)
# 14 12798 0.2129943       False   437     [0.2,0.24)
# 15 13951 0.2180379       True    429     [0.2,0.24)
# 16 14318 0.2180379       True    420     [0.2,0.24)
# 17 14527 0.2139610       False   439     [0.2,0.24)
# 18 14687 0.2186868       False   439     [0.2,0.24)
# 19 14830 0.2129943       False   440     [0.2,0.24)
# 20 15582 0.2320926       False   444     [0.2,0.24)
# 21 16191 0.2331683       True    419     [0.2,0.24)
# 22 16318 0.2331683       True    427     [0.2,0.24)
# 23 16334 0.2180379       True    430     [0.2,0.24)
# 24 16347 0.2026830       True    429     [0.2,0.24)
# 25 16365 0.2155439       True    429     [0.2,0.24)
