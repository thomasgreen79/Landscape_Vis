# %%
library(tidyverse)
library(ggplot2)

# %%
boa_8645 = read.csv("./structure_by_eigen_val_dist_NK_14_2_seed_19_boa_8645.csv", sep=";", colClasses = c("numeric", "numeric"))
boa_5110 = read.csv("./structure_by_eigen_val_dist_NK_14_2_seed_19_boa_5110.csv", sep=";", colClasses = c("numeric", "numeric"))
boa_452 = read.csv("./structure_by_eigen_val_dist_NK_14_2_seed_19_boa_452.csv", sep=";", colClasses = c("numeric", "numeric"))

# %%
#boa_8645["eigen_val"] = as.numeric(boa_8645[["eigen_val"]])

# %%
ggplot(boa_8645) +
  aes(x=eigen_val, y=count)+
  geom_point()
# Out:
# plot without title

# %%
ggplot(boa_5110) +
  aes(x=eigen_val, y=count)+
  geom_point()
# Out:
# plot without title

# %%
ggplot(boa_452) +
  aes(x=eigen_val, y=count)+
  geom_point()
# Out:
# plot without title

# %%
boa_8645 %>%
 filter(eigen_val > 0.2)
# Out:
#   eigen_val count
# 1 0.2333979 1
# 2 0.2546062 1
# 3 0.2883354 1
# 4 0.3181690 1
# 5 0.3950008 1
# 6 0.5203411 1
# 7 0.5333204 1
# 8 0.6201960 1

# %%
boa_5110 %>%
 filter(eigen_val == 0.001)
# Out:
#   eigen_val count
# 1 0.001     1048
